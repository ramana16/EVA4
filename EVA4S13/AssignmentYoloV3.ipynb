# %% [markdown]
# <a href="https://colab.research.google.com/github/ramana16/EVA4/blob/master/EVA4S13/AssignmentYoloV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ramana16/YoloV3.git
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 1017, done.
# remote: Counting objects: 100% (1017/1017), done.
# remote: Compressing objects: 100% (980/980), done.
# remote: Total 1173 (delta 0), reused 1015 (delta 0), pack-reused 156
# Receiving objects: 100% (1173/1173), 15.63 MiB | 34.93 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.5.1+cu101 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
ls
# Out:
# gdrive/  sample_data/  YoloV3/  YoloV322/  YoloV3old/  YoloV3ws/

# %%
cd YoloV3/
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %%
cp "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/Weights/yolov3-spp-ultralytics.pt" "weights/"

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# 2020-07-05 11:22:20.199831: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.29987e+07 parameters, 6.29987e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 3854.70it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 106.94it/s]
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 100 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=100, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# 2020-07-05 11:27:55.978287: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (495 found, 14 missing, 1 empty, 0 duplicate, for 510 images): 100% 510/510 [00:00<00:00, 5911.21it/s]
# Caching images (0.3GB): 100% 510/510 [00:00<00:00, 683.44it/s]
# Reading image shapes: 100% 510/510 [00:00<00:00, 7589.18it/s]
# ...

# %% [markdown]
# prevent timeout.
# sasas
# sasa
#
#
# ffflllllll

# %%
# !cp "weights/last.pt" "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/last.pt"

# %%
# !python detect.py --conf-thres 0.1 --output  "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/vidOutput" --source "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/Missilevideo.mp4"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/vidOutput', save_txt=False, source='/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/Missilevideo.mp4', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# video 1/1 (1/291) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/Missilevideo.mp4: 384x512 Done. (0.093s)
# video 1/1 (2/291) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/Missilevideo.mp4: 384x512 Done. (0.082s)
# video 1/1 (3/291) /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/Missilevideo.mp4: 384x512 Done. (0.081s)
# ...

# %%
# !python detect.py --conf-thres 0.3 --output "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/ffmpegBoxed" --source "/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/ffmpegInput"
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.3, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/customdata/custom.names', output='/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/ffmpegBoxed', save_txt=False, source='/content/gdrive/My Drive/Colab Notebooks/EVA4/S13/ffmpegInput', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# image 1/291 /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/ffmpegInput/$filename001.png: 384x512 Done. (0.092s)
# image 2/291 /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/ffmpegInput/$filename002.png: 384x512 Done. (0.092s)
# image 3/291 /content/gdrive/My Drive/Colab Notebooks/EVA4/S13/ffmpegInput/$filename003.png: 384x512 Done. (0.092s)
# ...
